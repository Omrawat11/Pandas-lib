# %%
import pandas as pd

# %%
a = {
    'Name': ['Gojo', 'Sukuna', 'Yuji', 'Mahoraga','Yuta', 'Megumi', 'Toji', 'Maki'],
    'Age': [23,100,19,453,32,25,34,25],
    'Score': [80,60,97,47,63,84,73,68]
}

# %%
data = pd.DataFrame(a)
data
# Out:
#        Name  Age  Score
# 0      Gojo   23     80
# 1    Sukuna  100     60
# 2      Yuji   19     97
# 3  Mahoraga  453     47
# 4      Yuta   32     63
# 5    Megumi   25     84
# 6      Toji   34     73
# 7      Maki   25     68

# %%
# Top -5 rows from upside
data.head(4)
# Out:
#        Name  Age  Score
# 0      Gojo   23     80
# 1    Sukuna  100     60
# 2      Yuji   19     97
# 3  Mahoraga  453     47

# %%
data.head() # if we not give value bydefault it will print 5 rows
# Out:
#        Name  Age  Score
# 0      Gojo   23     80
# 1    Sukuna  100     60
# 2      Yuji   19     97
# 3  Mahoraga  453     47
# 4      Yuta   32     63

# %%
# top -5 rows from downside
data.tail(3)
# Out:
#      Name  Age  Score
# 5  Megumi   25     84
# 6    Toji   34     73
# 7    Maki   25     68

# %%
data.tail() # if we not give value bydefault it will print 5 rows
# Out:
#        Name  Age  Score
# 3  Mahoraga  453     47
# 4      Yuta   32     63
# 5    Megumi   25     84
# 6      Toji   34     73
# 7      Maki   25     68

# %%
data.shape
# Out:
# (8, 3)

# %%
data.info() # to find the types of data .  which types are there (string(object), integer, float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    8 non-null      object
#  1   Age     8 non-null      int64
#  2   Score   8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
data.dtypes # finding datatypes in column
# Out:
# Name     object
# Age       int64
# Score     int64
# dtype: object

# %% [markdown]
# SELECTING COLUMNS AND ROWS

# %%
data['Age'] # for getting particular columns
# Out:
# 0     23
# 1    100
# 2     19
# 3    453
# 4     32
# 5     25
# 6     34
# 7     25
# Name: Age, dtype: int64

# %%
data[['Name','Age']] # for multiple columns
# Out:
#        Name  Age
# 0      Gojo   23
# 1    Sukuna  100
# 2      Yuji   19
# 3  Mahoraga  453
# 4      Yuta   32
# 5    Megumi   25
# 6      Toji   34
# 7      Maki   25

# %%
# .loc (df.loc[row_label,col_label])      FOR FINDING DIRECT LOCATION
data.loc[4,'Name'] # getting any particular value after giving index and column name
# Out:
# 'Yuta'

# %%
data.loc[1:5,['Name','Score']]
# Out:
#        Name  Score
# 1    Sukuna     60
# 2      Yuji     97
# 3  Mahoraga     47
# 4      Yuta     63
# 5    Megumi     84

# %%
# index location 
#.iloc (row_index,col_index)
data.iloc[3] #getting full detail of spcific location
# Out:
# Name     Mahoraga
# Age           453
# Score          47
# Name: 3, dtype: object

# %%
data.iloc[0:3,0:2]
# Out:
#      Name  Age
# 0    Gojo   23
# 1  Sukuna  100
# 2    Yuji   19

# %% [markdown]
# INDEX
# RamgeIndex (start=0, stop=9, steps= 1)

# %%
data.values # getting the value in form of list
# Out:
# array([['Gojo', 23, 80],
#        ['Sukuna', 100, 60],
#        ['Yuji', 19, 97],
#        ['Mahoraga', 453, 47],
#        ['Yuta', 32, 63],
#        ['Megumi', 25, 84],
#        ['Toji', 34, 73],
#        ['Maki', 25, 68]], dtype=object)

# %%
data.columns # getting the name of columns
# Out:
# Index(['Name', 'Age', 'Score'], dtype='object')

# %%
data.values.shape
# Out:
# (8, 3)

# %% [markdown]
# RENAME COLUMNS

# %%
c = data.rename(columns={'Score':'Marks'}) # #changing the column name or give new name 
c
# Out:
#        Name  Age  Marks
# 0      Gojo   23     80
# 1    Sukuna  100     60
# 2      Yuji   19     97
# 3  Mahoraga  453     47
# 4      Yuta   32     63
# 5    Megumi   25     84
# 6      Toji   34     73
# 7      Maki   25     68

# %%
c = data.rename(columns={'Score':'Marks','Age':'age'})
c
# Out:
#        Name  age  Marks
# 0      Gojo   23     80
# 1    Sukuna  100     60
# 2      Yuji   19     97
# 3  Mahoraga  453     47
# 4      Yuta   32     63
# 5    Megumi   25     84
# 6      Toji   34     73
# 7      Maki   25     68

# %% [markdown]
# SET INDEX

# %%
d = data.set_index('Name') ## we can change the index according to you
d
# Out:
#           Age  Score
# Name
# Gojo       23     80
# Sukuna    100     60
# Yuji       19     97
# Mahoraga  453     47
# Yuta       32     63
# Megumi     25     84
# Toji       34     73
# Maki       25     68

# %% [markdown]
# RESET INDEX

# %%
e = d.reset_index()
e
# Out:
#        Name  Age  Score
# 0      Gojo   23     80
# 1    Sukuna  100     60
# 2      Yuji   19     97
# 3  Mahoraga  453     47
# 4      Yuta   32     63
# 5    Megumi   25     84
# 6      Toji   34     73
# 7      Maki   25     68
